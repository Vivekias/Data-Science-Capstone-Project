# %% [markdown]
# ## Importing Libraries:-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the Dataset:-

# %%
df=pd.read_csv('CAR DETAILS.csv')
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# ## Analysing and cleaning the Dataset:-

# %%
## Checking the Datatypes:-

df.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
## Checking the shape of dataset:-

df.shape
# Out:
# (4340, 8)

# %%
## Converting price in Lacks rupees:- selling_price/100000

df['selling_price_in_lacks']=df['selling_price']/100000

## Conveting km_driven in lacks of km.:- km_driven/100000

df['km_driven_in_lacks']=df['km_driven']/100000

df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  selling_price_in_lacks  \
# 0  Individual       Manual   First Owner                    0.60
# 1  Individual       Manual   First Owner                    1.35
# 2  Individual       Manual   First Owner                    6.00
# 3  Individual       Manual   First Owner                    2.50
# 4  Individual       Manual  Second Owner                    4.50
#
#    km_driven_in_lacks
# 0                0.70
# 1                0.50
# 2                1.00
# 3                0.46
# 4                1.41

# %%
## Checking the null values:-

df.isnull().sum()
# Out:
# name                      0
# year                      0
# selling_price             0
# km_driven                 0
# fuel                      0
# seller_type               0
# transmission              0
# owner                     0
# selling_price_in_lacks    0
# km_driven_in_lacks        0
# dtype: int64

# %%
## Checking the categorical columns:-

df['fuel'].value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64

# %%
df['seller_type'].value_counts()
# Out:
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: seller_type, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %%
df['name'].value_counts().head(20)
# Out:
# Maruti Swift Dzire VDI            69
# Maruti Alto 800 LXI               59
# Maruti Alto LXi                   47
# Maruti Alto LX                    35
# Hyundai EON Era Plus              35
# Maruti Swift VDI BSIV             29
# Maruti Wagon R VXI BS IV          29
# Maruti Swift VDI                  27
# Hyundai EON Magna Plus            24
# Maruti Wagon R LXI Minor          24
# Maruti 800 AC                     23
# Maruti Wagon R LXI                23
# Maruti Ritz VDi                   22
# Mahindra XUV500 W8 2WD            22
# Hyundai i10 Magna                 22
# Hyundai Santro Xing GLS           21
# Renault KWID RXT                  21
# Maruti Alto K10 VXI               21
# Hyundai Creta 1.6 CRDi SX         19
# Renault Duster 85PS Diesel RxL    17
# Name: name, dtype: int64

# %% [markdown]
# ## Data Preprocessing:-
# ### converting all data in numerical form:-

# %%
from sklearn.preprocessing import LabelEncoder

# %%
## Making a copy of a dataframe:-

df2=df.copy()

df2=df2.drop(['selling_price','km_driven'],axis=1)
             
le=LabelEncoder()

df2['transmission']=le.fit_transform(df2['transmission'])
df2['seller_type']=le.fit_transform(df2['seller_type'])
df2['fuel']=le.fit_transform(df2['fuel'])
df2['owner']=le.fit_transform(df2['owner'])
df2['name']=le.fit_transform(df2['name'])

# %%
df2
# Out:
#       name  year  fuel  seller_type  transmission  owner  \
# 0      775  2007     4            1             1      0
# 1     1041  2007     4            1             1      0
# 2      505  2012     1            1             1      0
# 3      118  2017     4            1             1      0
# 4      279  2014     1            1             1      2
# ...    ...   ...   ...          ...           ...    ...
# 4335   602  2014     1            1             1      2
# 4336   601  2014     1            1             1      2
# 4337   777  2009     4            1             1      2
# 4338   381  2016     1            1             1      0
# 4339  1154  2016     4            1             1      0
#
#       selling_price_in_lacks  km_driven_in_lacks
# 0                    0.60000                0.70
# 1                    1.35000                0.50
# 2                    6.00000                1.00
# 3                    2.50000                0.46
# 4                    4.50000                1.41
# ...                      ...                 ...
# 4335                 4.09999                0.80
# 4336                 4.09999                0.80
# 4337                 1.10000                0.83
# 4338                 8.65000                0.90
# 4339                 2.25000                0.40
#
# [4340 rows x 8 columns]

# %% [markdown]
# ## Performing some EDA on Data:-

# %% [markdown]
# ### Classify on the basis of fuel used:-

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='fuel',hue='fuel')
plt.legend()
plt.grid()
plt.xlabel('Type of Fuel')
plt.ylabel('NO. of cars')
plt.title('Graph on the basis of fuel used')
plt.show()

# %% [markdown]
# ### Classify on the basis of owner type:-

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='owner',hue='owner')
plt.legend(bbox_to_anchor=(1,0,0.4,1))
plt.grid()
plt.xlabel('Type of owner')
plt.ylabel('NO. of cars')
plt.title('Graph on the basis of owner type')
plt.show()

# %% [markdown]
# ### Top 5  high price cars:-

# %%
r1=df[['name','selling_price_in_lacks']].sort_values(by='selling_price_in_lacks',ascending=False).head()
sns.set(rc={'figure.figsize':(6,8)})
sns.barplot(data=r1,x='name',y='selling_price_in_lacks')
plt.title(' Top 5 High Price Cars')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Top 5 Low price Car:-

# %%
r1=df[['name','selling_price_in_lacks']].sort_values(by='selling_price_in_lacks').head()
sns.set(rc={'figure.figsize':(6,8)})
sns.barplot(data=r1,x='selling_price_in_lacks',y='name')
plt.title(' Top 5 Low Price Cars')
sns.set_style('whitegrid')
plt.show()

# %% [markdown]
# ### Classify on the basis of transmission and fuel type:-

# %%
r2=df[['transmission','fuel']]
sns.countplot(data=r2,x='fuel',hue='transmission')
plt.title("count on the basis of transmission and fuel used")
plt.show()

# %% [markdown]
# ### Top 5 car with max driven km:-

# %%
r1=df[['name','km_driven_in_lacks']].sort_values(by='km_driven_in_lacks',ascending=False).head()
sns.set(rc={'figure.figsize':(6,8)})
sns.barplot(data=r1,x='km_driven_in_lacks',y='name')
plt.title(' Top 5 Max Driven Cars')
sns.set_style('whitegrid')
plt.show()

# %% [markdown]
# ### Top 5 car with min driven km:-

# %%
r1=df[['name','km_driven_in_lacks']].sort_values(by='km_driven_in_lacks').head()
sns.set(rc={'figure.figsize':(6,8)})
sns.barplot(data=r1,x='km_driven_in_lacks',y='name')
plt.title(' Top 5 Min Driven Cars')
plt.ylabel('Name of Car')
plt.xlabel('KM driven in lacks')
sns.set_style('whitegrid')
plt.show()

# %% [markdown]
# ### Classify on the basis of seller type:-

# %%
r2=df['seller_type'].value_counts()
r2.plot.pie(autopct='%.2f%%',legend=True)
plt.legend(bbox_to_anchor=(1,0,0,1))
plt.title('Classifiction on the basis of Seller Types:')
plt.show()

# %% [markdown]
# ### Classification on the basis of owner type with avg car price:-

# %%
r4=df[['owner','selling_price_in_lacks']].groupby('owner')['selling_price_in_lacks'].mean()
r4.plot.bar(color=('red','green','blue','orange','maroon'))
plt.xlabel('Owner Type')
plt.ylabel('Avg. Price in Lacks')
plt.show()

# %% [markdown]
# ### Heatmap for checking corelation:-

# %%
corr=df2.corr()
plt.figure(figsize=(18,15))
sns.heatmap(data=corr,annot=True,cmap='RdBu')
plt.show()

# %% [markdown]
# ## Prepare Data for Machine Learning Model:-
# ### Selecting Independent x & Dependent y variables:-

# %%
x=df2.drop('selling_price_in_lacks',axis=1)
y=df2['selling_price_in_lacks']
print(x.shape,y.shape)
# Out:
# (4340, 7) (4340,)

# %% [markdown]
# ### Preprocess the x and y variable using Standard Scaler:-

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x_sc=sc.fit_transform(x)
print(x_sc)
# Out:
# [[ 0.05852176 -1.44507431  1.01499338 ...  0.33927557 -0.66507931
#    0.08113906]
#  [ 0.72352031 -1.44507431  1.01499338 ...  0.33927557 -0.66507931
#   -0.3476891 ]
#  [-0.61647677 -0.2587948  -0.97405145 ...  0.33927557 -0.66507931
#    0.7243813 ]
#  ...
#  [ 0.06352175 -0.97056251  1.01499338 ...  0.33927557  0.95651856
#    0.35987736]
#  [-0.92647609  0.69022881 -0.97405145 ...  0.33927557 -0.66507931
#    0.50996722]
#  [ 1.0060197   0.69022881  1.01499338 ...  0.33927557 -0.66507931
#   -0.56210318]]

# %% [markdown]
# ### Spilt the data into train and test format:-

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_sc,y,test_size=0.3,random_state=101)
print('x_train_shape:',x_train.shape,'x-test_shape:',x_test.shape)
print('y_train_shape:',y_train.shape,'y_test_shape:',y_test.shape)
# Out:
# x_train_shape: (3038, 7) x-test_shape: (1302, 7)
# y_train_shape: (3038,) y_test_shape: (1302,)

# %% [markdown]
# ### Importing the Evalution metrics and creating a function for applying that:-

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def met(y_test,y_pred):
    print(mean_squared_error(y_test,y_pred))
    print(mean_absolute_error(y_test,y_pred))
    print(r2_score(y_test,y_pred))
def mscore(model):
    print('Train Score',model.score(x_train,y_train))
    print('Test Score',model.score(x_test,y_test))

# %% [markdown]
# ### Importing ML Models:-

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor

# %% [markdown]
# ## Applying the Linear Regression Model:-

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
## prediction the value:-

y_pred_lr=lr.predict(x_test)
print(y_pred_lr.shape)
# Out:
# (1302,)

# %% [markdown]
# ### Checking MAE , MSE, R2_score and Model score:-

# %%
met(y_test,y_pred_lr)
# Out:
# 17.32987338597188
# 2.3027614775072687
# 0.50201932555846

# %%
mscore(lr)
# Out:
# Train Score 0.4246699216584282
# Test Score 0.50201932555846

# %% [markdown]
# ## Applying KNN Model:-

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
## prediction the value:-

y_pred_knn=knn.predict(x_test)
print(y_pred_knn.shape)
# Out:
# (1302,)

# %% [markdown]
# ### Checking MAE , MSE, R2_score and Model score:-

# %%
met(y_test,y_pred_knn)
# Out:
# 9.459297723068953
# 1.5459740184331796
# 0.7281833885935787

# %%
mscore(knn)
# Out:
# Train Score 0.7357567629585093
# Test Score 0.7281833885935787

# %% [markdown]
# ## Applying Decision Tree Regressor Model:-

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
## prediction the value:-

y_pred_dt=dt.predict(x_test)
print(y_pred_dt.shape)
# Out:
# (1302,)

# %% [markdown]
# ### Checking MAE , MSE, R2_score and Model score:-

# %%
met(y_test,y_pred_dt)
# Out:
# 17.85009323267619
# 1.378456697388633
# 0.48707060525624524

# %%
mscore(dt)
# Out:
# Train Score 0.9999162754566882
# Test Score 0.48707060525624524

# %% [markdown]
# # Applying Bagging Ensemble MOdel:-

# %%
bagg=BaggingRegressor(base_estimator=dt)
bagg.fit(x_train,y_train)
# Out:
# BaggingRegressor(base_estimator=DecisionTreeRegressor())

# %%
## prediction the value:-

y_pred_bagg=bagg.predict(x_test)
print(y_pred_bagg.shape)
# Out:
# (1302,)

# %% [markdown]
# ### Checking MAE , MSE, R2_score and Model score:-

# %%
met(y_test,y_pred_bagg)
# Out:
# 5.643022270356967
# 1.1062825948357837
# 0.8378455529654524

# %%
mscore(bagg)
# Out:
# Train Score 0.9611007477812245
# Test Score 0.8378455529654524

# %% [markdown]
# # Checking the best Model:

# %%
best_mod=pd.DataFrame({'Model Name':['Linear Regression','KNN','Decision Tree Regressor','Bagging Regression'],'Train Score':[lr.score(x_train,y_train),knn.score(x_train,y_train),dt.score(x_train,y_train),bagg.score(x_train,y_train)],'Test Socre':[lr.score(x_test,y_test),knn.score(x_test,y_test),dt.score(x_test,y_test),bagg.score(x_test,y_test)]})
best_mod.head()
# Out:
#                 Model Name  Train Score  Test Socre
# 0        Linear Regression     0.424670    0.502019
# 1                      KNN     0.735757    0.728183
# 2  Decision Tree Regressor     0.999916    0.487071
# 3       Bagging Regression     0.961101    0.837846

# %% [markdown]
# # So, the best Model is Bagging Regressor.

# %% [markdown]
# ## Saving the best Model (Bagging Regressor):-

# %%
import pickle

# %%
pickle.dump(bagg,open('bagging.pkl','wb'))
loaded_model=pickle.load(open('bagging.pkl','rb'))

# %%
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.9611007477812245

# %% [markdown]
# ## Creating a random dataset by selecting 20 data and checking best Model on it:-

# %%
rand_20=df2[250:270]
rand_20.to_csv('rand_20.csv')
rand_20
# Out:
#      name  year  fuel  seller_type  transmission  owner  \
# 250   922  2018     4            1             1      0
# 251   820  2017     4            0             1      0
# 252   206  2006     1            1             1      4
# 253   410  2019     4            1             1      0
# 254   446  2017     1            0             1      0
# 255   881  2017     1            0             1      0
# 256   474  2013     4            1             1      0
# 257  1311  2006     1            1             1      2
# 258  1154  2018     4            1             1      0
# 259   775  2002     4            1             1      2
# 260  1016  2017     1            0             1      0
# 261   351  2009     4            1             1      0
# 262   581  2017     1            0             1      0
# 263   882  2017     1            1             1      2
# 264  1316  2002     1            1             1      0
# 265   764  2010     1            1             1      0
# 266  1009  2017     1            1             1      0
# 267   885  2014     4            1             1      0
# 268   579  2009     1            1             1      2
# 269   814  2007     4            1             1      0
#
#      selling_price_in_lacks  km_driven_in_lacks
# 250                 2.00000              0.1000
# 251                 6.25000              0.5200
# 252                 1.10000              1.2000
# 253                 8.00000              0.1124
# 254                 4.90000              0.6600
# 255                 8.80000              0.6400
# 256                 2.90000              0.4900
# 257                 1.15999              1.0000
# 258                 3.60000              0.2650
# 259                 0.65000              1.0000
# 260                 6.85000              0.7200
# 261                 3.00000              0.5000
# 262                 6.80000              0.4400
# 263                10.00000              0.6000
# 264                 1.00000              1.2000
# 265                 1.60000              1.3000
# 266                 4.50000              0.7000
# 267                 6.00000              0.2000
# 268                 1.80000              0.6000
# 269                 1.00000              1.9500

# %% [markdown]
# ### Selecting x and y in random dataset:-

# %%
x=rand_20.drop('selling_price_in_lacks',axis=1)
y=rand_20['selling_price_in_lacks']
print(x.shape,y.shape)
# Out:
# (20, 7) (20,)

# %% [markdown]
# ### Standardize the random dataset:-

# %%
sc=StandardScaler()
x_sc=sc.fit_transform(x)
print(x_sc)
# Out:
# [[ 0.47298794  0.97554965  1.1055416   0.57735027  0.         -0.53881591
#   -1.37149026]
#  [ 0.13371389  0.79489231  1.1055416  -1.73205081  0.         -0.53881591
#   -0.4269842 ]
#  [-1.90858285 -1.19233847 -0.90453403  0.57735027  0.          3.05329013
#    1.10221608]
#  [-1.23003475  1.156207    1.1055416   0.57735027  0.         -0.53881591
#   -1.34360484]
#  [-1.11029097  0.79489231 -0.90453403 -1.73205081  0.         -0.53881591
#   -0.11214885]
#  [ 0.33661308  0.79489231 -0.90453403 -1.73205081  0.         -0.53881591
#   -0.15712533]
#  [-1.01715691  0.07226294  1.1055416   0.57735027  0.         -0.53881591
#   -0.49444892]
#  [ 1.76688604 -1.19233847 -0.90453403  0.57735027  0.          1.25723711
#    0.65245129]
#  [ 1.2446701   0.97554965  1.1055416   0.57735027  0.         -0.53881591
#   -1.00043431]
#  [-0.01596584 -1.91496784  1.1055416   0.57735027  0.          1.25723711
#    0.65245129]
#  [ 0.78565226  0.79489231 -0.90453403 -1.73205081  0.         -0.53881591
#    0.02278059]
#  [-1.4262815  -0.65036644  1.1055416   0.57735027  0.         -0.53881591
#   -0.47196068]
#  [-0.66125178  0.79489231 -0.90453403 -1.73205081  0.         -0.53881591
#   -0.60689012]
#  [ 0.33993929  0.79489231 -0.90453403  0.57735027  0.          1.25723711
#   -0.24707829]
#  [ 1.78351712 -1.91496784 -0.90453403  0.57735027  0.         -0.53881591
#    1.10221608]
#  [-0.05255422 -0.46970909 -0.90453403  0.57735027  0.         -0.53881591
#    1.32709848]
#  [ 0.76236875  0.79489231 -0.90453403  0.57735027  0.         -0.53881591
#   -0.02219589]
#  [ 0.34991794  0.25292028  1.1055416   0.57735027  0.         -0.53881591
#   -1.14660787]
#  [-0.66790421 -0.65036644 -0.90453403  0.57735027  0.          1.25723711
#   -0.24707829]
#  [ 0.11375659 -1.01168112  1.1055416   0.57735027  0.         -0.53881591
#    2.78883404]]

# %% [markdown]
# ### Spliting the random dataset:-

# %%
x_train,x_test,y_train,y_test=train_test_split(x_sc,y,test_size=0.25,random_state=1)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (15, 7) (5, 7)
# (15,) (5,)

# %% [markdown]
# ### Applying the saved best model:-

# %%
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.6411949706386381
